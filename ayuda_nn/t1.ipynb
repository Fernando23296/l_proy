# %%
import numpy

# %%
def nn(m1,m2,w1,w2,b):
    z=w1*m1+w2*m2+b
    return sigmoid(z)
def sigmoid(x):
    return (1/(1+numpy.exp(-x)))

# %%
w1=numpy.random.rand()
w2=numpy.random.rand()
b=numpy.random.rand()

# %%
nn(3,1.5,w1,w2,b)
# Out:
# 0.9811453753986845

# %%
def costo(b):
    return (b-4)**2

def slope_costo(b):
    return 2*(b-4)

# %%
b=8

# %%
b =b-0.5*slope_costo(b)
print(b)
# Out:
# 5.31072

# %%
b =1
for i in range(1000):
    b=b-0.1*slope_costo(b)
    print(b)
# Out:
# 1.6
# 2.08
# 2.464
# 2.7712
# 3.01696
# 3.213568
# 3.3708544
# 3.49668352
# 3.597346816
# 3.6778774528
# 3.74230196224
# 3.793841569792
# 3.8350732558336
# 3.86805860466688
# 3.894446883733504
# 3.9155575069868034
# 3.932446005589443
# 3.945956804471554
# 3.9567654435772432
# 3.9654123548617948
# 3.9723298838894356
# 3.9778639071115487
# 3.982291125689239
# 3.985832900551391
# 3.988666320441113
# 3.9909330563528904
# 3.9927464450823122
# 3.99419715606585
# 3.99535772485268
# 3.996286179882144
# 3.997028943905715
# 3.9976231551245722
# 3.9980985240996576
# 3.9984788192797263
# 3.998783055423781
# 3.999026444339025
# 3.99922115547122
# 3.9993769243769757
# 3.9995015395015807
# 3.9996012316012646
# 3.9996809852810116
# 3.999744788224809
# 3.9997958305798473
# 3.999836664463878
# 3.9998693315711025
# 3.999895465256882
# 3.9999163722055053
# 3.999933097764404
# 3.9999464782115233
# 3.9999571825692186
# 3.999965746055375
# 3.9999725968443
# 3.99997807747544
# 3.999982461980352
# ...
