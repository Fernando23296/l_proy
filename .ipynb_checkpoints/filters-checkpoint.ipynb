# %%
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
imagen = cv2.imread('ex9_erosion.png', 0)
kernel = np.ones((3, 3), np.uint8)

# %%
transformacion = cv2.dilate(imagen, kernel, iterations=1) - cv2.erode(imagen, kernel, iterations=1)

# %%
plt.imshow(transformacion)

# %% [markdown]
# # Canny Detector

# %%
import cv2
 
# Cargamos la imagen
original = cv2.imread("ex8_erosion.png")
cv2.imshow("original", original)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-7-a2f77fc22cfc> in <module>()
#       3 # Cargamos la imagen
#       4 original = cv2.imread("imagenes/monedas.jpg")
# ----> 5 cv2.imshow("original", original)
#
# error: OpenCV(3.4.2) /opt/concourse/worker/volumes/live/9523d527-1b9e-48e0-7ed0-a36adde286f0/volume/opencv-suite_1535558719691/work/modules/highgui/src/window.cpp:356: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'imshow'
